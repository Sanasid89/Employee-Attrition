# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('/content/archive.zip')

# %%
df.sample()
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 572   29        No  Travel_Rarely        657  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 572                27          3        Medical              1
#
#      EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 572             793  ...                         1            80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 572                 1                 11                      3
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 572               2               8                  7
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 572                        1                     1
#
# [1 rows x 35 columns]

# %%
pd.set_option('display.max_columns',None)     #this code is used to show/display each and every column of the dataset

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe()   #this gives the descriptive statstics of the data like mean(average) ,standard deviation ,minimum ,maximum value
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.duplicated().sum()    #check whether there is any duplicate values or not
# Out:
# np.int64(0)

# %%
df.duplicated().value_counts()
# Out:
# False    1470
# Name: count, dtype: int64

# %% [markdown]
# # Imbalanced Target Variable
# From the below graph, we can see that the target column 'Attrition' is highly unbalanced. We need to balance it using some statistical method.
#
# Because imbalaced dataset creates imbalanced learning ,means model may gives high accuracy while not learning pattern in the data

# %%
# ATTRITION IS TARGET VARAIBLE

df['Attrition'].value_counts().plot(kind='bar',edgecolor='black',colormap='viridis')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Department vs. Attrition

# %%
sns.countplot(x='Department',hue='Attrition',data=df,edgecolor='black',palette='rocket')
plt.title('Department vs Attrition')
plt.show()

# %% [markdown]
# ### Education Field vs. Attrition

# %%
sns.countplot(x='EducationField',hue='Attrition',data=df,edgecolor='black',palette='crest')
plt.title('EducationField vs Attrition')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# ## JobRole vs. Attrition

# %%
sns.countplot(x='JobRole',hue='Attrition',data=df,edgecolor='black',palette='coolwarm')
plt.title('JobRole vs Attrition')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ## Gender vs. Attrition

# %%
sns.countplot(x='Gender',hue='Attrition',data=df,edgecolor='black',palette='flare')
plt.title('Gender vs Attrition')
plt.xticks(rotation=360)
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
df.groupby('Gender')['Attrition'].value_counts()
# Out:
# Gender  Attrition
# Female  No           501
#         Yes           87
# Male    No           732
#         Yes          150
# Name: count, dtype: int64

# %% [markdown]
# ### This code analyzes the relationship between 'Gender' and 'Attrition' by grouping the data by 'Gender' and then counting the occurrences of 'Attrition' within each gender category. This provides a breakdown of attrition counts for both male and female employees.

# %% [markdown]
# ### Attrition Rate Calculation for Female and Male Employees

# %%
87/(501+87)
# Out:
# 0.14795918367346939

# %%
150/(732+150)
# Out:
# 0.17006802721088435

# %%
sns.boxplot(x=df['MonthlyIncome'], y=df['YearsAtCompany'])
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='YearsAtCompany'>

# %% [markdown]
# ### Correlation Matrix

# %%
numerical_cols = ['Age', 'DailyRate', 'MonthlyIncome', 'YearsAtCompany']
df_numerical = df[numerical_cols]

# Calculate the correlation matrix
correlation_matrix = df_numerical.corr()

# Visualize the correlation matrix using a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='Pastel1', fmt=".2f")
plt.title('Correlation Matrix of Selected Numerical Columns')
plt.show()

# %% [markdown]
# ## Categorical Columns

# %%
df['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %% [markdown]
# ## Label Encoding
# We use label encoding to convert categorical data into numbers, because most machine learning algorithms require numerical input.

# %%
df['Attrition']=df['Attrition'].replace({'Yes':1,'No':0})
# Out:
# /tmp/ipython-input-303182462.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Attrition']=df['Attrition'].replace({'Yes':1,'No':0})

# %%
df['Gender']=df['Gender'].map({'Male':0,'Female':1})

# %%
df['Over18']=df['Over18'].map({'N':0,'Y':1})

# %%
df['OverTime']=df['OverTime'].map({'Yes':1,'No':0})

# %%
from sklearn.preprocessing import LabelEncoder

encoding_cols=['BusinessTravel','Department','JobRole','MaritalStatus','EducationField']
label_encoders={}
for column in encoding_cols:
  label_encoders[column]=LabelEncoder()
  df[column]=label_encoders[column].fit_transform(df[column])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               1              1               1
# 1          1               1              1               2
# 2          2               4              1               4
# 3          4               1              1               5
# 4          1               3              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %% [markdown]
# ## Training ML Model
# For Training the machine learnIng model we'll split the data into Training and Testing samples
#
# Training data is the one on which Model is build , while testing data is some randomly selected data kept aside for checking how good model is.

# %%
X = df.drop('Attrition', axis=1)      #Input Features
y = df['Attrition']         #Output features

# %% [markdown]
# ## Resampling
# We need resampling because the target variable ('Attrition') is imbalanced. This means there are significantly more instances of one class (e.g., 'No Attrition') than the other ('Yes Attrition'). If we train a model on such imbalanced data without resampling, the model might become biased towards the majority class and perform poorly in predicting the minority class.
#
#
# Resampling techniques help to balance the dataset, allowing the model to learn patterns from both classes effectively.

# %% [markdown]
# ## Oversampling and Undersampling
#
# **Oversampling:** Increasing the number of instances in the minority class to balance the dataset.
#
# **Undersampling:** Decreasing the number of instances in the majority class to balance the dataset.
#
#
# In this we are going to use oversampling nor undersampling to avoid data loss.

# %%
from collections import Counter
print('Before OverSamplin:')
print(Counter(y))
from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler(random_state=42)
X_over,y_over=ros.fit_resample(X,y)
print('After Oversampling:')
print(Counter(y_over))
# Out:
# Before OverSamplin:
# Counter({0: 1233, 1: 237})
# After Oversampling:
# Counter({1: 1233, 0: 1233})

# %% [markdown]
# ### Split the data into training and testing datasets

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_over, y_over,test_size=0.2,random_state=42)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,f1_score,mean_absolute_error,classification_report

# %%
logreg=LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction=logreg.predict(X_test)
cnf_matrix= confusion_matrix(y_test,prediction)
print('accuracy_score',accuracy_score(y_test,prediction))
print('f1_score',f1_score(y_test,prediction))
print('MAE',mean_absolute_error(y_test,prediction))
print(cnf_matrix)
# Out:
# accuracy_score 0.6437246963562753
# f1_score 0.6575875486381323
# MAE 0.3562753036437247
# [[149 101]
#  [ 75 169]]

# %%
sns.heatmap(cnf_matrix,annot=True,fmt='g')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.60      0.63       250
#            1       0.63      0.69      0.66       244
#
#     accuracy                           0.64       494
#    macro avg       0.65      0.64      0.64       494
# weighted avg       0.65      0.64      0.64       494

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
Random_forest_model=RandomForestClassifier()
Random_forest_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred=Random_forest_model.predict(X_test)
cnf_matrix=confusion_matrix(y_test,pred)
print('accuracy_score',accuracy_score(y_test,pred))
print('f1_score',f1_score(y_test,pred))
print('MAE',mean_absolute_error(y_test,pred))
print(cnf_matrix)
# Out:
# accuracy_score 0.9574898785425101
# f1_score 0.9574036511156186
# MAE 0.04251012145748988
# [[237  13]
#  [  8 236]]

# %%
sns.heatmap(cnf_matrix,annot=True,fmt='g')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       250
#            1       0.95      0.97      0.96       244
#
#     accuracy                           0.96       494
#    macro avg       0.96      0.96      0.96       494
# weighted avg       0.96      0.96      0.96       494

# %%
import pickle

# Pickle the trained Random Forest model
pickle.dump(Random_forest_model, open('random_forest_model.pkl', 'wb'))

# Pickle the processed dataframe
pickle.dump(df, open('df_processed.pkl', 'wb'))

print("Random Forest model and processed dataframe pickled successfully.")
# Out:
# Random Forest model and processed dataframe pickled successfully.
